# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# C:\Users\joaog\Anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
#read the file with the information from the game fifa_20
fifa20 = "data/players_20.csv"
fifa20_df = pd.read_csv(fifa20, encoding='utf8')

#sorting the df for the 200 most value players
fifa20_df_value = fifa20_df.sort_values(by='value_eur', ascending=False).head(200)

# %%
# cleaning the to select only columns of the data we need
fifa20_clean_df = fifa20_df_value[["short_name", "long_name","age", "club", "overall",\
                                   "potential", "value_eur", "nationality"]]
fifa20_clean_df
# Out:
#        short_name                       long_name  age                 club  \
# 2       Neymar Jr   Neymar da Silva Santos Junior   27  Paris Saint-Germain
# 0        L. Messi  Lionel Andrés Messi Cuccittini   32         FC Barcelona
# 10      K. Mbappé                   Kylian Mbappé   20  Paris Saint-Germain
# 5    K. De Bruyne                 Kevin De Bruyne   28      Manchester City
# 4       E. Hazard                     Eden Hazard   28          Real Madrid
# ..            ...                             ...  ...                  ...
# 276    K. Volland                   Kevin Volland   26  Bayer 04 Leverkusen
# 270      M. Götze                     Mario Götze   27    Borussia Dortmund
# 283     F. Kostić                    Filip Kostić   26  Eintracht Frankfurt
# 331   T. Ndombele          Tanguy NDombèlé Alvaro   22    Tottenham Hotspur
# 273  Willian José           Willian José da Silva   27        Real Sociedad
#
#      overall  potential  value_eur nationality
# 2         92         92  105500000      Brazil
# 0         94         94   95500000   Argentina
# 10        89         95   93500000      France
# 5         91         91   90000000     Belgium
# 4         91         91   90000000     Belgium
# ..       ...        ...        ...         ...
# 276       82         83   26500000     Germany
# 270       82         83   26000000     Germany
# 283       82         83   26000000      Serbia
# 331       81         89   26000000      France
# 273       82         83   26000000      Brazil
#
# [200 rows x 8 columns]

# %%
#read the file with the information scraped from transfermakt site
trsf = "data/transfermarkt.csv"
transfmarkt_df = pd.read_csv(trsf, encoding='utf8')
transfmarkt_df
# Out:
#                       Name                                              Image  \
# 0            Kylian Mbappé  https://tmssl.akamaized.net//images/portrait/s...
# 1          Raheem Sterling  https://tmssl.akamaized.net//images/portrait/s...
# 2                   Neymar  https://tmssl.akamaized.net//images/portrait/s...
# 3               Sadio Mané  https://tmssl.akamaized.net//images/portrait/s...
# 4            Mohamed Salah  https://tmssl.akamaized.net//images/portrait/s...
# 5               Harry Kane  https://tmssl.akamaized.net//images/portrait/s...
# 6          Kevin De Bruyne  https://tmssl.akamaized.net//images/portrait/s...
# 7             Lionel Messi  https://tmssl.akamaized.net//images/portrait/s...
# 8             Jadon Sancho  https://tmssl.akamaized.net//images/portrait/s...
# 9        Antoine Griezmann  https://tmssl.akamaized.net//images/portrait/s...
# 10             Eden Hazard  https://tmssl.akamaized.net//images/portrait/s...
# 11  Trent Alexander-Arnold  https://tmssl.akamaized.net//images/portrait/s...
# 12              João Félix  https://tmssl.akamaized.net//images/portrait/s...
# 13          Bernardo Silva  https://tmssl.akamaized.net//images/portrait/s...
# 14            N'Golo Kanté  https://tmssl.akamaized.net//images/portrait/s...
# 15              Leroy Sané  https://tmssl.akamaized.net//images/portrait/s...
# 16         Virgil van Dijk  https://tmssl.akamaized.net//images/portrait/s...
# 17              Paul Pogba  https://tmssl.akamaized.net//images/portrait/s...
# 18               Jan Oblak  https://tmssl.akamaized.net//images/portrait/s...
# 19         Frenkie de Jong  https://tmssl.akamaized.net//images/portrait/s...
# 20             Kai Havertz  https://tmssl.akamaized.net//images/portrait/s...
# 21               Dele Alli  https://tmssl.akamaized.net//images/portrait/s...
# 22             Saúl Ñíguez  https://tmssl.akamaized.net//images/portrait/s...
# 23         Roberto Firmino  https://tmssl.akamaized.net//images/portrait/s...
# 24                 Alisson  https://tmssl.akamaized.net//images/portrait/s...
#
#               Position Market Value
# 0       Centre-Forward    $228.00m
# 1          Left Winger    $182.40m
# 2          Left Winger    $182.40m
# 3          Left Winger    $171.00m
# 4         Right Winger    $171.00m
# 5       Centre-Forward    $171.00m
# 6   Attacking Midfield    $171.00m
# 7         Right Winger    $159.60m
# 8         Right Winger    $136.80m
# 9       Centre-Forward    $136.80m
# 10         Left Winger    $136.80m
# 11          Right-Back    $125.40m
# 12      Second Striker    $114.00m
# 13        Right Winger    $114.00m
# 14    Central Midfield    $114.00m
# 15         Left Winger    $114.00m
# 16         Centre-Back    $114.00m
# 17    Central Midfield    $114.00m
# 18          Goalkeeper    $114.00m
# 19    Central Midfield    $102.60m
# 20  Attacking Midfield    $102.60m
# 21  Attacking Midfield    $102.60m
# 22    Central Midfield    $102.60m
# 23      Centre-Forward    $102.60m
# 24          Goalkeeper    $102.60m

# %%
# using fuzzywuzzy
# create a function to macht the names on the transfermarkt df with the long and short names on the fifa_20 df

def match_names(name, list_names1,list_names2, min_score=0):
    # 0 score incase we don't get any matches
    max_score1 = 0
    max_score2 = 0

    # Returning empty name for no match as well
    max_name1 = ""
    max_name2 = ""

    # Iternating over all names (transfermartk df) in two list of names (shor and long in fifa_20 df)
    for name1 in list_names1:
        #Finding fuzzy match score
        score1 = fuzz.ratio(name, name1)
        # Checking if we are above our threshold and have a better score
        if (score1 > min_score) & (score1 > max_score1):
            max_name1 = name1
            max_score1 = score1
            
    for name2 in list_names2:
        #Finding fuzzy match score
        score2 = fuzz.ratio(name, name2)
        # Checking if we are above our threshold and have a better score
        if (score2 > min_score) & (score2 > max_score2):
            max_name2 = name2
            max_score2 = score2
            
    # return the names matched for the two lists
    return (max_name1, max_score1, max_name2, max_score2)

# %%
# matche the names on diferent dataframes
dict_list = []

# iterating over players in transfermarkt
for name in transfmarkt_df.Name:
    # Use our method to find best match, we can set a threshold here 
    match = match_names(name, fifa20_clean_df.short_name,fifa20_clean_df.long_name, 50)
    
    # New dict for storing data
    dict_ = {}
    dict_.update({"Name" : name})
    dict_.update({"short_name" : match[0]})
    dict_.update({"score_short" : match[1]})
    dict_.update({"long_name" : match[2]})
    dict_.update({"score_long" : match[3]})
    dict_list.append(dict_)
    
merge_table_names = pd.DataFrame(dict_list)

# Display results
merge_table_names
# Out:
#                       Name           short_name  score_short  \
# 0            Kylian Mbappé            K. Mbappé           73
# 1          Raheem Sterling          R. Sterling           77
# 2                   Neymar            Neymar Jr           80
# 3               Sadio Mané              S. Mané           71
# 4            Mohamed Salah             M. Salah           67
# 5               Harry Kane              H. Kane           71
# 6          Kevin De Bruyne         K. De Bruyne           81
# 7             Lionel Messi             L. Messi           70
# 8             Jadon Sancho            J. Sancho           76
# 9        Antoine Griezmann         A. Griezmann           76
# 10             Eden Hazard            E. Hazard           80
# 11  Trent Alexander-Arnold  T. Alexander-Arnold           88
# 12              João Félix           João Félix          100
# 13          Bernardo Silva       Bernardo Silva          100
# 14            N'Golo Kanté             N. Kanté           70
# 15              Leroy Sané              L. Sané           71
# 16         Virgil van Dijk          V. van Dijk           77
# 17              Paul Pogba             P. Pogba           78
# 18               Jan Oblak             J. Oblak           82
# 19         Frenkie de Jong           F. de Jong           72
# 20             Kai Havertz           K. Havertz           86
# 21               Dele Alli              D. Alli           75
# 22             Saúl Ñíguez                 Saúl           53
# 23         Roberto Firmino      Roberto Firmino          100
# 24                 Alisson              Alisson          100
#
#                                   long_name  score_long
# 0                             Kylian Mbappé         100
# 1                           Raheem Sterling         100
# 2                                                     0
# 3                                Sadio Mané         100
# 4                      Mohamed  Salah Ghaly          79
# 5                                Harry Kane         100
# 6                           Kevin De Bruyne         100
# 7            Lionel Andrés Messi Cuccittini          57
# 8                              Jadon Sancho         100
# 9                         Antoine Griezmann         100
# 10                              Eden Hazard         100
# 11                   Trent Alexander-Arnold         100
# 12                      João Félix Sequeira          69
# 13  Bernardo Mota Veiga de Carvalho e Silva          53
# 14                             N'Golo Kanté         100
# 15                               Leroy Sané         100
# 16                          Virgil van Dijk         100
# 17                               Paul Pogba         100
# 18                                Jan Oblak         100
# 19                          Frenkie de Jong         100
# 20                              Kai Havertz         100
# 21                            Bamidele Alli          73
# 22                     Saúl Ñíguez Esclápez          71
# 23      Roberto Firmino Barbosa de Oliveira          60
# 24                                                    0

# %%
# merge the matching names with the fifa_20 df and Trasnfermarkt df
fifa_names_df =  pd.merge(merge_table_names, fifa20_clean_df,  how='left',\
                             left_on=['short_name' or'long_name'], right_on = ['short_name'or'long_name'])

fifa_transfermark_df = pd.merge(fifa_names_df, transfmarkt_df,  how='left',\
                             left_on=['Name'], right_on = ['Name'])
fifa_transfermark_df
# Out:
#                       Name           short_name  score_short  \
# 0            Kylian Mbappé            K. Mbappé           73
# 1          Raheem Sterling          R. Sterling           77
# 2                   Neymar            Neymar Jr           80
# 3               Sadio Mané              S. Mané           71
# 4            Mohamed Salah             M. Salah           67
# 5               Harry Kane              H. Kane           71
# 6          Kevin De Bruyne         K. De Bruyne           81
# 7             Lionel Messi             L. Messi           70
# 8             Jadon Sancho            J. Sancho           76
# 9        Antoine Griezmann         A. Griezmann           76
# 10             Eden Hazard            E. Hazard           80
# 11  Trent Alexander-Arnold  T. Alexander-Arnold           88
# 12              João Félix           João Félix          100
# 13          Bernardo Silva       Bernardo Silva          100
# 14            N'Golo Kanté             N. Kanté           70
# 15              Leroy Sané              L. Sané           71
# 16         Virgil van Dijk          V. van Dijk           77
# 17              Paul Pogba             P. Pogba           78
# 18               Jan Oblak             J. Oblak           82
# 19         Frenkie de Jong           F. de Jong           72
# 20             Kai Havertz           K. Havertz           86
# 21               Dele Alli              D. Alli           75
# 22             Saúl Ñíguez                 Saúl           53
# 23         Roberto Firmino      Roberto Firmino          100
# 24                 Alisson              Alisson          100
#
#                                 long_name_x  score_long  \
# 0                             Kylian Mbappé         100
# 1                           Raheem Sterling         100
# 2                                                     0
# 3                                Sadio Mané         100
# 4                      Mohamed  Salah Ghaly          79
# 5                                Harry Kane         100
# 6                           Kevin De Bruyne         100
# 7            Lionel Andrés Messi Cuccittini          57
# 8                              Jadon Sancho         100
# 9                         Antoine Griezmann         100
# 10                              Eden Hazard         100
# 11                   Trent Alexander-Arnold         100
# 12                      João Félix Sequeira          69
# 13  Bernardo Mota Veiga de Carvalho e Silva          53
# 14                             N'Golo Kanté         100
# 15                               Leroy Sané         100
# 16                          Virgil van Dijk         100
# 17                               Paul Pogba         100
# 18                                Jan Oblak         100
# 19                          Frenkie de Jong         100
# 20                              Kai Havertz         100
# 21                            Bamidele Alli          73
# 22                     Saúl Ñíguez Esclápez          71
# 23      Roberto Firmino Barbosa de Oliveira          60
# 24                                                    0
#
#                                 long_name_y  age                 club  \
# 0                             Kylian Mbappé   20  Paris Saint-Germain
# 1                           Raheem Sterling   24      Manchester City
# 2             Neymar da Silva Santos Junior   27  Paris Saint-Germain
# 3                                Sadio Mané   27            Liverpool
# 4                      Mohamed  Salah Ghaly   27            Liverpool
# 5                                Harry Kane   25    Tottenham Hotspur
# 6                           Kevin De Bruyne   28      Manchester City
# 7            Lionel Andrés Messi Cuccittini   32         FC Barcelona
# 8                              Jadon Sancho   19    Borussia Dortmund
# 9                         Antoine Griezmann   28         FC Barcelona
# 10                              Eden Hazard   28          Real Madrid
# 11                   Trent Alexander-Arnold   20            Liverpool
# 12                      João Félix Sequeira   19      Atlético Madrid
# 13  Bernardo Mota Veiga de Carvalho e Silva   24      Manchester City
# 14                             N'Golo Kanté   28              Chelsea
# 15                               Leroy Sané   23      Manchester City
# 16                          Virgil van Dijk   27            Liverpool
# 17                               Paul Pogba   26    Manchester United
# 18                                Jan Oblak   26      Atlético Madrid
# 19                          Frenkie de Jong   22         FC Barcelona
# 20                              Kai Havertz   20  Bayer 04 Leverkusen
# 21                            Bamidele Alli   23    Tottenham Hotspur
# 22                     Saúl Ñíguez Esclápez   24      Atlético Madrid
# 23      Roberto Firmino Barbosa de Oliveira   27            Liverpool
# 24                    Alisson Ramses Becker   26            Liverpool
#
#     overall  potential  value_eur  nationality  \
# 0        89         95   93500000       France
# 1        88         90   73000000      England
# 2        92         92  105500000       Brazil
# 3        88         88   62000000      Senegal
# 4        90         90   80500000        Egypt
# 5        89         91   83000000      England
# 6        91         91   90000000      Belgium
# 7        94         94   95500000    Argentina
# 8        84         92   44500000      England
# 9        89         89   69000000       France
# 10       91         91   90000000      Belgium
# 11       83         89   32000000      England
# 12       80         93   28000000     Portugal
# 13       87         90   64000000     Portugal
# 14       89         90   66000000       France
# 15       86         92   61000000      Germany
# 16       90         91   78000000  Netherlands
# 17       88         91   72500000       France
# 18       91         93   77500000     Slovenia
# 19       85         91   52000000  Netherlands
# 20       84         92   46000000      Germany
# 21       84         89   41500000      England
# 22       85         89   49500000        Spain
# 23       86         87   52000000       Brazil
# 24       89         91   58000000       Brazil
#
#                                                 Image            Position  \
# 0   https://tmssl.akamaized.net//images/portrait/s...      Centre-Forward
# 1   https://tmssl.akamaized.net//images/portrait/s...         Left Winger
# 2   https://tmssl.akamaized.net//images/portrait/s...         Left Winger
# 3   https://tmssl.akamaized.net//images/portrait/s...         Left Winger
# 4   https://tmssl.akamaized.net//images/portrait/s...        Right Winger
# 5   https://tmssl.akamaized.net//images/portrait/s...      Centre-Forward
# 6   https://tmssl.akamaized.net//images/portrait/s...  Attacking Midfield
# 7   https://tmssl.akamaized.net//images/portrait/s...        Right Winger
# 8   https://tmssl.akamaized.net//images/portrait/s...        Right Winger
# 9   https://tmssl.akamaized.net//images/portrait/s...      Centre-Forward
# 10  https://tmssl.akamaized.net//images/portrait/s...         Left Winger
# 11  https://tmssl.akamaized.net//images/portrait/s...          Right-Back
# 12  https://tmssl.akamaized.net//images/portrait/s...      Second Striker
# 13  https://tmssl.akamaized.net//images/portrait/s...        Right Winger
# 14  https://tmssl.akamaized.net//images/portrait/s...    Central Midfield
# 15  https://tmssl.akamaized.net//images/portrait/s...         Left Winger
# 16  https://tmssl.akamaized.net//images/portrait/s...         Centre-Back
# 17  https://tmssl.akamaized.net//images/portrait/s...    Central Midfield
# 18  https://tmssl.akamaized.net//images/portrait/s...          Goalkeeper
# 19  https://tmssl.akamaized.net//images/portrait/s...    Central Midfield
# 20  https://tmssl.akamaized.net//images/portrait/s...  Attacking Midfield
# 21  https://tmssl.akamaized.net//images/portrait/s...  Attacking Midfield
# 22  https://tmssl.akamaized.net//images/portrait/s...    Central Midfield
# 23  https://tmssl.akamaized.net//images/portrait/s...      Centre-Forward
# 24  https://tmssl.akamaized.net//images/portrait/s...          Goalkeeper
#
#    Market Value
# 0     $228.00m
# 1     $182.40m
# 2     $182.40m
# 3     $171.00m
# 4     $171.00m
# 5     $171.00m
# 6     $171.00m
# 7     $159.60m
# 8     $136.80m
# 9     $136.80m
# 10    $136.80m
# 11    $125.40m
# 12    $114.00m
# 13    $114.00m
# 14    $114.00m
# 15    $114.00m
# 16    $114.00m
# 17    $114.00m
# 18    $114.00m
# 19    $102.60m
# 20    $102.60m
# 21    $102.60m
# 22    $102.60m
# 23    $102.60m
# 24    $102.60m

# %%
# clean the fifa_transfermarkt DF 
fifa_transfermark_df = fifa_transfermark_df [['Name', 'long_name_y','age', 'club', 'overall', 'potential', 'value_eur',\
                                              'nationality','Image', 'Position', 'Market Value']]
fifa_transfermark_df
# Out:
#                       Name                              long_name_y  age  \
# 0            Kylian Mbappé                            Kylian Mbappé   20
# 1          Raheem Sterling                          Raheem Sterling   24
# 2                   Neymar            Neymar da Silva Santos Junior   27
# 3               Sadio Mané                               Sadio Mané   27
# 4            Mohamed Salah                     Mohamed  Salah Ghaly   27
# 5               Harry Kane                               Harry Kane   25
# 6          Kevin De Bruyne                          Kevin De Bruyne   28
# 7             Lionel Messi           Lionel Andrés Messi Cuccittini   32
# 8             Jadon Sancho                             Jadon Sancho   19
# 9        Antoine Griezmann                        Antoine Griezmann   28
# 10             Eden Hazard                              Eden Hazard   28
# 11  Trent Alexander-Arnold                   Trent Alexander-Arnold   20
# 12              João Félix                      João Félix Sequeira   19
# 13          Bernardo Silva  Bernardo Mota Veiga de Carvalho e Silva   24
# 14            N'Golo Kanté                             N'Golo Kanté   28
# 15              Leroy Sané                               Leroy Sané   23
# 16         Virgil van Dijk                          Virgil van Dijk   27
# 17              Paul Pogba                               Paul Pogba   26
# 18               Jan Oblak                                Jan Oblak   26
# 19         Frenkie de Jong                          Frenkie de Jong   22
# 20             Kai Havertz                              Kai Havertz   20
# 21               Dele Alli                            Bamidele Alli   23
# 22             Saúl Ñíguez                     Saúl Ñíguez Esclápez   24
# 23         Roberto Firmino      Roberto Firmino Barbosa de Oliveira   27
# 24                 Alisson                    Alisson Ramses Becker   26
#
#                    club  overall  potential  value_eur  nationality  \
# 0   Paris Saint-Germain       89         95   93500000       France
# 1       Manchester City       88         90   73000000      England
# 2   Paris Saint-Germain       92         92  105500000       Brazil
# 3             Liverpool       88         88   62000000      Senegal
# 4             Liverpool       90         90   80500000        Egypt
# 5     Tottenham Hotspur       89         91   83000000      England
# 6       Manchester City       91         91   90000000      Belgium
# 7          FC Barcelona       94         94   95500000    Argentina
# 8     Borussia Dortmund       84         92   44500000      England
# 9          FC Barcelona       89         89   69000000       France
# 10          Real Madrid       91         91   90000000      Belgium
# 11            Liverpool       83         89   32000000      England
# 12      Atlético Madrid       80         93   28000000     Portugal
# 13      Manchester City       87         90   64000000     Portugal
# 14              Chelsea       89         90   66000000       France
# 15      Manchester City       86         92   61000000      Germany
# 16            Liverpool       90         91   78000000  Netherlands
# 17    Manchester United       88         91   72500000       France
# 18      Atlético Madrid       91         93   77500000     Slovenia
# 19         FC Barcelona       85         91   52000000  Netherlands
# 20  Bayer 04 Leverkusen       84         92   46000000      Germany
# 21    Tottenham Hotspur       84         89   41500000      England
# 22      Atlético Madrid       85         89   49500000        Spain
# 23            Liverpool       86         87   52000000       Brazil
# 24            Liverpool       89         91   58000000       Brazil
#
#                                                 Image            Position  \
# 0   https://tmssl.akamaized.net//images/portrait/s...      Centre-Forward
# 1   https://tmssl.akamaized.net//images/portrait/s...         Left Winger
# 2   https://tmssl.akamaized.net//images/portrait/s...         Left Winger
# 3   https://tmssl.akamaized.net//images/portrait/s...         Left Winger
# 4   https://tmssl.akamaized.net//images/portrait/s...        Right Winger
# 5   https://tmssl.akamaized.net//images/portrait/s...      Centre-Forward
# 6   https://tmssl.akamaized.net//images/portrait/s...  Attacking Midfield
# 7   https://tmssl.akamaized.net//images/portrait/s...        Right Winger
# 8   https://tmssl.akamaized.net//images/portrait/s...        Right Winger
# 9   https://tmssl.akamaized.net//images/portrait/s...      Centre-Forward
# 10  https://tmssl.akamaized.net//images/portrait/s...         Left Winger
# 11  https://tmssl.akamaized.net//images/portrait/s...          Right-Back
# 12  https://tmssl.akamaized.net//images/portrait/s...      Second Striker
# 13  https://tmssl.akamaized.net//images/portrait/s...        Right Winger
# 14  https://tmssl.akamaized.net//images/portrait/s...    Central Midfield
# 15  https://tmssl.akamaized.net//images/portrait/s...         Left Winger
# 16  https://tmssl.akamaized.net//images/portrait/s...         Centre-Back
# 17  https://tmssl.akamaized.net//images/portrait/s...    Central Midfield
# 18  https://tmssl.akamaized.net//images/portrait/s...          Goalkeeper
# 19  https://tmssl.akamaized.net//images/portrait/s...    Central Midfield
# 20  https://tmssl.akamaized.net//images/portrait/s...  Attacking Midfield
# 21  https://tmssl.akamaized.net//images/portrait/s...  Attacking Midfield
# 22  https://tmssl.akamaized.net//images/portrait/s...    Central Midfield
# 23  https://tmssl.akamaized.net//images/portrait/s...      Centre-Forward
# 24  https://tmssl.akamaized.net//images/portrait/s...          Goalkeeper
#
#    Market Value
# 0     $228.00m
# 1     $182.40m
# 2     $182.40m
# 3     $171.00m
# 4     $171.00m
# 5     $171.00m
# 6     $171.00m
# 7     $159.60m
# 8     $136.80m
# 9     $136.80m
# 10    $136.80m
# 11    $125.40m
# 12    $114.00m
# 13    $114.00m
# 14    $114.00m
# 15    $114.00m
# 16    $114.00m
# 17    $114.00m
# 18    $114.00m
# 19    $102.60m
# 20    $102.60m
# 21    $102.60m
# 22    $102.60m
# 23    $102.60m
# 24    $102.60m

# %%
# clean the Market Value column
real_prices = fifa_transfermark_df['Market Value'].values.T.tolist()
real_value = []
for price in real_prices:
    new = price.split("$")
    new1 = new[1].split("m")
    real_value.append(new1[0])
print(real_value)
# Out:
# ['228.00', '182.40', '182.40', '171.00', '171.00', '171.00', '171.00', '159.60', '136.80', '136.80', '136.80', '125.40', '114.00', '114.00', '114.00', '114.00', '114.00', '114.00', '114.00', '102.60', '102.60', '102.60', '102.60', '102.60', '102.60']

# %%
# replace the old Market Value column from string to float
real_df = pd.DataFrame(real_value)
real_df = real_df[0].astype(float)
real_df = real_df*1000000


fifa_transfermark_df['Market Value'] = real_df
fifa_transfermark_df
# Out:
# C:\Users\joaog\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                       Name                              long_name_y  age  \
# 0            Kylian Mbappé                            Kylian Mbappé   20
# 1          Raheem Sterling                          Raheem Sterling   24
# 2                   Neymar            Neymar da Silva Santos Junior   27
# 3               Sadio Mané                               Sadio Mané   27
# 4            Mohamed Salah                     Mohamed  Salah Ghaly   27
# 5               Harry Kane                               Harry Kane   25
# 6          Kevin De Bruyne                          Kevin De Bruyne   28
# 7             Lionel Messi           Lionel Andrés Messi Cuccittini   32
# 8             Jadon Sancho                             Jadon Sancho   19
# 9        Antoine Griezmann                        Antoine Griezmann   28
# 10             Eden Hazard                              Eden Hazard   28
# 11  Trent Alexander-Arnold                   Trent Alexander-Arnold   20
# 12              João Félix                      João Félix Sequeira   19
# 13          Bernardo Silva  Bernardo Mota Veiga de Carvalho e Silva   24
# 14            N'Golo Kanté                             N'Golo Kanté   28
# 15              Leroy Sané                               Leroy Sané   23
# 16         Virgil van Dijk                          Virgil van Dijk   27
# 17              Paul Pogba                               Paul Pogba   26
# 18               Jan Oblak                                Jan Oblak   26
# 19         Frenkie de Jong                          Frenkie de Jong   22
# 20             Kai Havertz                              Kai Havertz   20
# 21               Dele Alli                            Bamidele Alli   23
# 22             Saúl Ñíguez                     Saúl Ñíguez Esclápez   24
# 23         Roberto Firmino      Roberto Firmino Barbosa de Oliveira   27
# 24                 Alisson                    Alisson Ramses Becker   26
#
#                    club  overall  potential  value_eur  nationality  \
# 0   Paris Saint-Germain       89         95   93500000       France
# 1       Manchester City       88         90   73000000      England
# 2   Paris Saint-Germain       92         92  105500000       Brazil
# 3             Liverpool       88         88   62000000      Senegal
# 4             Liverpool       90         90   80500000        Egypt
# 5     Tottenham Hotspur       89         91   83000000      England
# 6       Manchester City       91         91   90000000      Belgium
# 7          FC Barcelona       94         94   95500000    Argentina
# 8     Borussia Dortmund       84         92   44500000      England
# 9          FC Barcelona       89         89   69000000       France
# 10          Real Madrid       91         91   90000000      Belgium
# 11            Liverpool       83         89   32000000      England
# 12      Atlético Madrid       80         93   28000000     Portugal
# 13      Manchester City       87         90   64000000     Portugal
# 14              Chelsea       89         90   66000000       France
# 15      Manchester City       86         92   61000000      Germany
# 16            Liverpool       90         91   78000000  Netherlands
# 17    Manchester United       88         91   72500000       France
# 18      Atlético Madrid       91         93   77500000     Slovenia
# 19         FC Barcelona       85         91   52000000  Netherlands
# 20  Bayer 04 Leverkusen       84         92   46000000      Germany
# 21    Tottenham Hotspur       84         89   41500000      England
# 22      Atlético Madrid       85         89   49500000        Spain
# 23            Liverpool       86         87   52000000       Brazil
# 24            Liverpool       89         91   58000000       Brazil
#
#                                                 Image            Position  \
# 0   https://tmssl.akamaized.net//images/portrait/s...      Centre-Forward
# 1   https://tmssl.akamaized.net//images/portrait/s...         Left Winger
# 2   https://tmssl.akamaized.net//images/portrait/s...         Left Winger
# 3   https://tmssl.akamaized.net//images/portrait/s...         Left Winger
# 4   https://tmssl.akamaized.net//images/portrait/s...        Right Winger
# 5   https://tmssl.akamaized.net//images/portrait/s...      Centre-Forward
# 6   https://tmssl.akamaized.net//images/portrait/s...  Attacking Midfield
# 7   https://tmssl.akamaized.net//images/portrait/s...        Right Winger
# 8   https://tmssl.akamaized.net//images/portrait/s...        Right Winger
# 9   https://tmssl.akamaized.net//images/portrait/s...      Centre-Forward
# 10  https://tmssl.akamaized.net//images/portrait/s...         Left Winger
# 11  https://tmssl.akamaized.net//images/portrait/s...          Right-Back
# 12  https://tmssl.akamaized.net//images/portrait/s...      Second Striker
# 13  https://tmssl.akamaized.net//images/portrait/s...        Right Winger
# 14  https://tmssl.akamaized.net//images/portrait/s...    Central Midfield
# 15  https://tmssl.akamaized.net//images/portrait/s...         Left Winger
# 16  https://tmssl.akamaized.net//images/portrait/s...         Centre-Back
# 17  https://tmssl.akamaized.net//images/portrait/s...    Central Midfield
# 18  https://tmssl.akamaized.net//images/portrait/s...          Goalkeeper
# 19  https://tmssl.akamaized.net//images/portrait/s...    Central Midfield
# 20  https://tmssl.akamaized.net//images/portrait/s...  Attacking Midfield
# 21  https://tmssl.akamaized.net//images/portrait/s...  Attacking Midfield
# 22  https://tmssl.akamaized.net//images/portrait/s...    Central Midfield
# 23  https://tmssl.akamaized.net//images/portrait/s...      Centre-Forward
# 24  https://tmssl.akamaized.net//images/portrait/s...          Goalkeeper
#
#     Market Value
# 0    228000000.0
# 1    182400000.0
# 2    182400000.0
# 3    171000000.0
# 4    171000000.0
# 5    171000000.0
# 6    171000000.0
# 7    159600000.0
# 8    136800000.0
# 9    136800000.0
# 10   136800000.0
# 11   125400000.0
# 12   114000000.0
# 13   114000000.0
# 14   114000000.0
# 15   114000000.0
# 16   114000000.0
# 17   114000000.0
# 18   114000000.0
# 19   102600000.0
# 20   102600000.0
# 21   102600000.0
# 22   102600000.0
# 23   102600000.0
# 24   102600000.0

# %%
# writing the new data to a new csv file
fifa_transfermark_df.to_csv('data/fifa_transfermark_df.csv',index=False)
