# %%
# Dependencies
import requests
from bs4 import BeautifulSoup

import pandas as pd

# %%
# URL of page to be scraped
url = 'https://www.transfermarkt.us/spieler-statistik/wertvollstespieler/marktwertetop/plus/0/galerie/0?ausrichtung=alle&spielerposition_id=alle&altersklasse=alle&jahrgang=0&land_id=0&kontinent_id=0&yt0=Show'

# %%
# to be able to scrape this website we need to use 'User Agents'
# more info about user agents in 'https://webscraping.com/blog/User-agents/'
# You can find your User-Agent at 'http://whatsmyuseragent.com/'
headers = {'User-Agent': 
           'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36'}

# %%
# Retrieve page with the requests module
html = requests.get(url, headers=headers)

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(html.content, 'html.parser')

# %%
# Examine the results, then determine element that contains sought info
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!-- paulirish.com/2008/conditional-stylesheets-vs-css-hacks-answer-neither/ -->
# <!--[if IE 7]>
# <html class="ie7 oldie" lang="en"> <![endif]-->
# <!--[if IE 8]>
# <html class="no-js lt-ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="x-ua-compatible"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="#1a3151" name="theme-color">
#    <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#    <link href="/favicon-16x16.png" rel="shortcut icon" sizes="16x16"/>
#    <link href="/android-chrome-192x192.png" rel="shortcut icon" sizes="192x192"/>
#    <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed"/>
#    <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, user-scalable=no" name="viewport">
#     <meta content="" name="description"/>
# ...

# %%
results = soup.find("div", class_ = "responsive-table")
print(results)
# Out:
# <div class="responsive-table">
# <div class="grid-view" id="yw1">
# <div class="summary"></div>
# <table class="items">
# <thead>
# <tr>
# <th class="zentriert" id="yw1_c0">#</th><th class="" id="yw1_c1">Player</th><th class="zentriert" id="yw1_c2"><a class="sort-link" href="/spieler-statistik/wertvollstespieler/marktwertetop/plus/ausrichtung/alle/spielerposition_id/alle/altersklasse/alle/jahrgang/0/land_id/0/kontinent_id/0/yt0/Show/0//sort/alter.desc">Age</a></th><th class="zentriert" id="yw1_c3">Nat.</th><th class="zentriert" id="yw1_c4">Club</th><th class="rechts" id="yw1_c5"><a class="sort-link" href="/spieler-statistik/wertvollstespieler/marktwertetop/plus/ausrichtung/alle/spielerposition_id/alle/altersklasse/alle/jahrgang/0/land_id/0/kontinent_id/0/yt0/Show/0//sort/marktwert.desc">Market value</a></th></tr>
# </thead>
# <tbody>
# <tr class="odd">
# ...

# %%
#getting the Players Names
names =[]
players = result.findAll("a", {"class" : "spielprofil_tooltip"})
for player in players:
    player = player.text
    names.append(player)
# Out:
# Kylian Mbappé
# Raheem Sterling
# Neymar
# Sadio Mané
# Mohamed Salah
# Harry Kane
# Kevin De Bruyne
# Lionel Messi
# Jadon Sancho
# Antoine Griezmann
# Eden Hazard
# Trent Alexander-Arnold
# João Félix
# Bernardo Silva
# N'Golo Kanté
# Leroy Sané
# Virgil van Dijk
# Paul Pogba
# Jan Oblak
# Frenkie de Jong
# Kai Havertz
# Dele Alli
# Saúl Ñíguez
# Roberto Firmino
# Alisson

# %%
#getting the Players picture link
img_links =[]
pictures = result.findAll("img",{"class":"bilderrahmen-fixed"})
for img in pictures:
    img = img['src']
    img_links.append(img)
# Out:
# https://tmssl.akamaized.net//images/portrait/small/342229-1533629004.jpg?lm=1533629019
# https://tmssl.akamaized.net//images/portrait/small/134425-1577051521.jpg?lm=1577051537
# https://tmssl.akamaized.net//images/portrait/small/68290-1529677270.jpg?lm=1529677295
# https://tmssl.akamaized.net//images/portrait/small/200512-1559901727.jpg?lm=1559901744
# https://tmssl.akamaized.net//images/portrait/small/148455-1546611604.jpg?lm=1546611628
# https://tmssl.akamaized.net//images/portrait/small/132098-1522316722.jpg?lm=1522316737
# https://tmssl.akamaized.net//images/portrait/small/88755-1515761259.jpg?lm=1515761270
# https://tmssl.akamaized.net//images/portrait/small/28003-1510231943.jpg?lm=1510231982
# https://tmssl.akamaized.net//images/portrait/small/401173-1567086818.jpg?lm=1567086859
# https://tmssl.akamaized.net//images/portrait/small/125781-1564143733.jpg?lm=1564143749
# https://tmssl.akamaized.net//images/portrait/small/50202-1537861483.jpg?lm=1537861501
# ...

# %%
#getting the Players position
pl_positions =[]
positions = result.findAll('table', {"class": "inline-table"})
for position in positions:
    position = (position.findAll('td')[2]).text
    pl_positions.append(position)

# %%
#getting the Players market value
mkt_values =[]
values = result.findAll("td", {"class":"rechts hauptlink"})
for value in values:
    value = value.text
    mkt_values.append(value)
# Out:
# $228.00m
# $182.40m
# $182.40m
# $171.00m
# $171.00m
# $171.00m
# $171.00m
# $159.60m
# $136.80m
# $136.80m
# $136.80m
# $125.40m
# $114.00m
# $114.00m
# $114.00m
# $114.00m
# $114.00m
# $114.00m
# $114.00m
# $102.60m
# $102.60m
# $102.60m
# $102.60m
# $102.60m
# $102.60m

# %%
# Create a Dataframe and export to a .csv file
df = pd.DataFrame(list(zip(names,img_links,pl_positions,mkt_values)), \
                  columns =['Name', 'Image', "Position", "Market Value"]) 
df.to_csv('data/transfermarkt.csv',index=False)
df
# Out:
#                       Name                                              Image  \
# 0            Kylian Mbappé  https://tmssl.akamaized.net//images/portrait/s...
# 1          Raheem Sterling  https://tmssl.akamaized.net//images/portrait/s...
# 2                   Neymar  https://tmssl.akamaized.net//images/portrait/s...
# 3               Sadio Mané  https://tmssl.akamaized.net//images/portrait/s...
# 4            Mohamed Salah  https://tmssl.akamaized.net//images/portrait/s...
# 5               Harry Kane  https://tmssl.akamaized.net//images/portrait/s...
# 6          Kevin De Bruyne  https://tmssl.akamaized.net//images/portrait/s...
# 7             Lionel Messi  https://tmssl.akamaized.net//images/portrait/s...
# 8             Jadon Sancho  https://tmssl.akamaized.net//images/portrait/s...
# 9        Antoine Griezmann  https://tmssl.akamaized.net//images/portrait/s...
# 10             Eden Hazard  https://tmssl.akamaized.net//images/portrait/s...
# ...
